# %%
import Classes
import GUI
import MealFrameClass
import FunctionsOfTheGUI as Fotgui

'''
For those using jupyter notebooks, remember to restart kernal after every run. Otherise it will give you an error.
Other than that, if you dont, just copy and paste this code into whatever you use to run code. 
So long as you've set up the other python files correctly, you should be golden.
'''

GUI.Window.mainloop() #Well, I guess the GUI wont let anything work if its opened first. Like having somthing work outside of a functions domain.
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\Spencer\anaconda3\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Spencer\Desktop\School\School Fall 2025 Enviroment\CIS\MealFrameClass.py", line 29, in <lambda>
#     self.SelectedMeals.bind('<ButtonRelease-1>', lambda event: Fotgui.GrabSelection(event, self.SelectedMeals, True))
#                                                                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Spencer\Desktop\School\School Fall 2025 Enviroment\CIS\FunctionsOfTheGUI.py", line 44, in GrabSelection
#     Name, Index = NameOfSelect(List)
#     ^^^^^^^^^^^
# TypeError: cannot unpack non-iterable NoneType object
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\Spencer\anaconda3\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Spencer\Desktop\School\School Fall 2025 Enviroment\CIS\MealFrameClass.py", line 29, in <lambda>
#     self.SelectedMeals.bind('<ButtonRelease-1>', lambda event: Fotgui.GrabSelection(event, self.SelectedMeals, True))
#                                                                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Spencer\Desktop\School\School Fall 2025 Enviroment\CIS\FunctionsOfTheGUI.py", line 44, in GrabSelection
#     Name, Index = NameOfSelect(List)
#     ^^^^^^^^^^^
# TypeError: cannot unpack non-iterable NoneType object
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\Spencer\anaconda3\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Spencer\Desktop\School\School Fall 2025 Enviroment\CIS\MealFrameClass.py", line 29, in <lambda>
#     self.SelectedMeals.bind('<ButtonRelease-1>', lambda event: Fotgui.GrabSelection(event, self.SelectedMeals, True))
#                                                                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Spencer\Desktop\School\School Fall 2025 Enviroment\CIS\FunctionsOfTheGUI.py", line 44, in GrabSelection
#     Name, Index = NameOfSelect(List)
#     ^^^^^^^^^^^
# TypeError: cannot unpack non-iterable NoneType object
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\Spencer\anaconda3\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\Spencer\Desktop\School\School Fall 2025 Enviroment\CIS\MealFrameClass.py", line 29, in <lambda>
#     self.SelectedMeals.bind('<ButtonRelease-1>', lambda event: Fotgui.GrabSelection(event, self.SelectedMeals, True))
#                                                                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Spencer\Desktop\School\School Fall 2025 Enviroment\CIS\FunctionsOfTheGUI.py", line 44, in GrabSelection
#     Name, Index = NameOfSelect(List)
#     ^^^^^^^^^^^
# TypeError: cannot unpack non-iterable NoneType object
# Whitelist: []
# Blacklist: []
# No filters, all added except for frozen meals
# Accepted: ['Popcorn', 'Tacos', 'Hamburger', 'Ham Sandwich', 'Turkey Sandwich', 'Soup', 'Pizza', 'Hot Dogs']
# 8
# Whitelist: []
# Blacklist: []
# No filters, all added except for frozen meals
# Accepted: ['Popcorn', 'Tacos', 'Hamburger', 'Ham Sandwich', 'Turkey Sandwich', 'Soup', 'Pizza', 'Hot Dogs']
# 8
# Whitelist: []
# Blacklist: []
# No filters, all added except for frozen meals
# Accepted: ['Popcorn', 'Tacos', 'Hamburger', 'Ham Sandwich', 'Turkey Sandwich', 'Soup', 'Pizza', 'Hot Dogs']
# 8
# Whitelist: []
# Blacklist: []
# No filters, all added except for frozen meals
# Accepted: ['Popcorn', 'Tacos', 'Hamburger', 'Ham Sandwich', 'Turkey Sandwich', 'Soup', 'Pizza', 'Hot Dogs']
# 8
# Whitelist: []
# Blacklist: []
# No filters, all added except for frozen meals
# Accepted: ['Popcorn', 'Tacos', 'Hamburger', 'Ham Sandwich', 'Turkey Sandwich', 'Soup', 'Pizza', 'Hot Dogs']
# 8
# Whitelist: []
# Blacklist: []
# No filters, all added except for frozen meals
# Accepted: ['Popcorn', 'Tacos', 'Hamburger', 'Ham Sandwich', 'Turkey Sandwich', 'Soup', 'Pizza', 'Hot Dogs']
# 8
# Whitelist: []
# Blacklist: []
# No filters, all added except for frozen meals
# Accepted: ['Popcorn', 'Tacos', 'Hamburger', 'Ham Sandwich', 'Turkey Sandwich', 'Soup', 'Pizza', 'Hot Dogs']
# 8
# Whitelist: []
# Blacklist: []
# No filters, all added except for frozen meals
# Accepted: ['Popcorn', 'Tacos', 'Hamburger', 'Ham Sandwich', 'Turkey Sandwich', 'Soup', 'Pizza', 'Hot Dogs']
# 8
# Whitelist: []
# Blacklist: []
# No filters, all added except for frozen meals
# Accepted: ['Popcorn', 'Tacos', 'Hamburger', 'Ham Sandwich', 'Turkey Sandwich', 'Soup', 'Pizza', 'Hot Dogs']
# 8
# Whitelist: []
# Blacklist: []
# No filters, all added except for frozen meals
# Accepted: ['Popcorn', 'Tacos', 'Hamburger', 'Ham Sandwich', 'Turkey Sandwich', 'Soup', 'Pizza', 'Hot Dogs']
# 8
# Whitelist: ['Snack']
# Blacklist: []
# Accepted: ['Popcorn']
# Accepted: ['Popcorn']
# 1
# Whitelist: ['Snack']
# Blacklist: []
# Accepted: ['Popcorn']
# Accepted: ['Popcorn']
# 1
# Whitelist: ['Snack']
# Blacklist: []
# Accepted: ['Popcorn']
# Accepted: ['Popcorn']
# 1
# Whitelist: ['Snack']
# Blacklist: []
# Accepted: ['Popcorn']
# Accepted: ['Popcorn']
# 1
# Whitelist: ['Snack']
# Blacklist: []
# Accepted: ['Popcorn']
# Accepted: ['Popcorn']
# 1
# Whitelist: ['Snack']
# Blacklist: []
# Accepted: ['Popcorn']
# Accepted: ['Popcorn']
# 1
# Whitelist: ['Snack']
# Blacklist: []
# Accepted: ['Popcorn']
# Accepted: ['Popcorn']
# 1
# Whitelist: ['Snack']
# Blacklist: []
# Accepted: ['Popcorn']
# Accepted: ['Popcorn']
# 1
# Whitelist: ['Snack']
# Blacklist: []
# Accepted: ['Popcorn']
# Accepted: ['Popcorn']
# 1
# Whitelist: ['Snack']
# Blacklist: []
# Accepted: ['Popcorn']
# Accepted: ['Popcorn']
# 1
# Whitelist: ['Snack']
# Blacklist: []
# Accepted: ['Popcorn']
# Accepted: ['Popcorn']
# 1

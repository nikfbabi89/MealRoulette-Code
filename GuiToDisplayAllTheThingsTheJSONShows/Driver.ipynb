# %%
import json
import MealData
import Classes
import GUI
import FunctionsOfTheGUI as Fotgui

'''
Remember to restart kernal after every run. Otherise it will give you an error.
'''
Fotgui.InnitMealList(GUI.MealList, Classes.Meals)

GUI.Window.mainloop() #Well, I guess the GUI wont let anything work if its opened first. Like having somthing work outside of a functions domain.



''' Debug Stuff
print('PRINTING THY MEALS\n\n', Meals)
#Not Now. Roulette = MealRoulette(Meals)

for i in Meals:
    print('\n')
    i.TellMeEverything()
    print('\n')

#print(MealData.JsonData)
'''
# Out:
# []
# []
# 8
# []
# []
# 8
# []
# []
# 8
# []
# []
# 8
# []
# []
# 8
# []
# []
# 8
# []
# []
# 8
# []
# []
# 8
# []
# []
# 8
# ['Quick']
# []
# Removed Item From Acceptability
# Removed Item From Acceptability
# Removed Item From Acceptability
# Removed Item From Acceptability
# Removed Item From Acceptability
# 5
# ['Quick']
# []
# Removed Item From Acceptability
# Removed Item From Acceptability
# Removed Item From Acceptability
# Removed Item From Acceptability
# Removed Item From Acceptability
# 5
# ['Quick']
# []
# Removed Item From Acceptability
# Removed Item From Acceptability
# Removed Item From Acceptability
# Removed Item From Acceptability
# Removed Item From Acceptability
# 5
# ['Quick']
# []
# Removed Item From Acceptability
# Removed Item From Acceptability
# Removed Item From Acceptability
# Removed Item From Acceptability
# Removed Item From Acceptability
# 5
# ['Quick']
# []
# Removed Item From Acceptability
# Removed Item From Acceptability
# ...
